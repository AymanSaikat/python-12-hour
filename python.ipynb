# %% [markdown]
# <a href="https://colab.research.google.com/github/AymanSaikat/python-12-hour/blob/main/python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("i love you")
# Out:
# i love you

# %%
#strings type data >> here is demo

first_name = "Ayman"
middle_name = ""
last_name = "Saikat"
food = "Mango"
email = "aymansaikat@email.com"

full_name = first_name +" "+ middle_name+" "+ last_name

print(f"Hello! My Name is {full_name}")
print(f"i love {food}")
print(f"My email is: {email}")
# Out:
# Hello! My Name is Ayman  Saikat
# i love Mango
# My email is: aymansaikat@email.com

# %%
#integgggers type data >> here is demo

age
