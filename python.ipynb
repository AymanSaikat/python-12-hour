# %%
print("i love you")
# Out:
# i love you

# %%
#strings type data >> here is demo

first_name = "Ayman"
middle_name = ""
last_name = "Saikat"
food = "Mango"
email = "aymansaikat@email.com"

full_name = first_name +" "+ middle_name+" "+ last_name

print(f"Hello! My Name is {full_name}")
print(f"i love {food}")
print(f"My email is: {email}")
# Out:
# Hello! My Name is Ayman  Saikat
# i love Mango
# My email is: aymansaikat@email.com

# %%
#integers type data >> here is demo

age = 25
quantity = 67
num_of_student = 30

print(f"I\'m {age} years old")
print(f"I\'m going to buy {quantity} items")
print(f"In my class there are {num_of_student} students")
# Out:
# I'm 25 years old
# I'm going to buy 67 items
# In my class there are 30 students

# %%
#float type data >> here is demo

food_price = 5.99
GPA = 4.25
distance = 12.67

print(f"The price of the mango is ${food_price}")
print(f"My GPA is {GPA}")
print(f"I ran {distance}KM")
# Out:
# The price of the mango is $5.99
# My GPA is 4.25
# I ran 12.67KM

# %%
#boolean type data >>

love = True
love = Flase

if love:
  print("i love you")
else:
  print("i love you so much")
# Out:
# i love you so much

# %%
#practice >> 1 from part-2

user_name = "Bro Coode"
year = 2024
pi = 3.1416
is_admin = True


print(user_name)
print(year)
print(pi)

if is_admin:
  print("you are admin")
else:
  print("you are not admin")
# Out:
# Bro Coode
# 2024
# 3.1416
# you are admin

# %%
#typecasting = str(), int(), float(), bool()

full_name = "Ayman Saikat"
age = 25
GPA = 4.25
is_student = True

#typecasting for str type to bool
print(type(full_name))

full_name = bool(full_name)

print(type(full_name))
print(full_name)

#typecasting for int type to float & float to int
print(type(age))
print(type(GPA))

age = float(age)
GPA = int(GPA)

print(type(age))
print(type(GPA))
print(age)
print(GPA)
# Out:
# <class 'str'>
# <class 'bool'>
# True
# <class 'int'>
# <class 'float'>
# <class 'float'>
# <class 'int'>
# 25.0
# 4

# %%
#input() type data how to work

input("hello! ")

    #input to print

input("do you love me? (Yes/No) : ")
print(f"i love you too")
# Out:
# hello! hi
# do you love me? (Yes/No) : yes
# i love you too

# %%
#input to print with data stoage and typecasting


name = input("what is your name?: ")

print(f"Hello, {name}! how are you")

age = int(input("how old are you?: "))
age = age + 1

print(f"Happly {age}th Birthday")
print(f"I love you {name}")
# Out:
# what is your name?: o
# Hello, o! how are you
# how old are you?: 21
# Happly 22th Birthday
# I love you o

# %%
#Exercise 1 rectangle area calculator

lenght = float(input("what is the lenght of the your area (cm): "))
width = float(input("what is the width of the your area (cm): "))

area = lenght * width

print(f"the total area is: {area}cm²")
# Out:
# what is the lenght of the your area (cm): 6.8
# what is the width of the your area (cm): 8.9
# the total area is: 60.52cm²

# %%
#excercise 2 shpping cart program

item = input("what item whould you like to buy?: ")
price = float(input(f"what is the price of {item}?: "))
quantity = int(input(f"how many {item} would you like?: "))

total = price *

print(f"you have bougth {quantity} x {item}/s")
print(f"your total amount is: {total}")
# Out:
# what item whould you like to buy?: mango
# what is the price of mango?: 2.6
# how many mango would you like?: 12
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_22170/2804142905.py in <cell line: 0>()
#       5 quantity = int(input(f"how many {item} would you like?: "))
#       6
# ----> 7 total = price * quantitiy
#       8
#       9 print(f"you have bougth {quantity} x {item}/s")
#
# NameError: name 'quantitiy' is not defined

# %%
#excercise 2 shpping cart program

item = input("what item whould you like to buy?: ")
price = float(input(f"what is the price of {item}?: "))
quantity = int(input(f"how many {item} would you like?: "))

total = price * quantity

print(f"you have bougth {quantity} x {item}/s")
print(f"your total amount is: ${total}")
# Out:
# what item whould you like to buy?: mango
# what is the price of mango?: 3.6
# how many mango would you like?: 12
# you have bougth 12 x mango/s
# your total amount is: $43.2

# %%
# Mad Libs! excercise
